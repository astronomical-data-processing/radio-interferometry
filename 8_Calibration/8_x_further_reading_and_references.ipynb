# %% [markdown]
# ***
#
# * [总目录](../0_Introduction/0_introduction.ipynb)
# * [术语表](../0_Introduction/1_glossary.ipynb)
# * [8. 校准](8_0_introduction.ipynb)
#     * 上一节： [8.4 第三代校准（3GC）](8_4_3gc.ipynb)
#     * 下一节： [第 9 章：实践部分](../9_Practical/9_1_visualisation-inspection.ipynb)
#
# ***

# %% [markdown]
# ## 8.x 兼容导航页：延伸阅读与参考文献
#
# 旧版目录和外部链接中仍可能指向 `8_x_further_reading_and_references.ipynb`。为保持链接稳定，本页保留为兼容入口；正式的章节收尾页已经统一为 [8.6 延伸阅读与参考文献](8_6_further_reading_and_references.ipynb)。
#
# 当前新版目录中的参考文献、阅读路线和第 9 章衔接说明均集中在 [8.6 延伸阅读与参考文献](8_6_further_reading_and_references.ipynb)。本页只承担旧链接过渡作用。

# %% [markdown]
# ***
