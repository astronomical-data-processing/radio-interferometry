# %% [markdown]
# ***
#
# * [总目录](../0_Introduction/0_introduction.ipynb)
# * [9. 实践部分](9_1_visualisation-inspection.ipynb)
#
# ***

# %% [markdown]
# # 兼容导航页：观测中的展宽
#
# 旧版目录仍可能指向 `9_3_Observing_smearing.ipynb`。当前新版内容已整理到 [9_6_averaging_and_smearing.ipynb](9_6_averaging_and_smearing.ipynb)，本页仅作为兼容入口保留。
