# %% [markdown]
# ***
# <a id='beginning'></a> <!--\label{beginning}-->
#
# * [总目录](../0_Introduction/0_introduction.ipynb)
# * [术语表](../0_Introduction/1_glossary.ipynb)
# * [4. 可见度空间](4_0_introduction.ipynb)
#     * 上一节：[4.6 傅里叶近似与 van Cittert-Zernike 定理](4_6_the_fourier_approximation_van_cittert-zernike_theorem.ipynb)
#     * 下一章：[5. 成像](../5_Imaging/5_0_introduction.ipynb)
#
# ***

# %% [markdown]
# ## 4.x 延伸阅读与参考文献 <a id='visib:sec:refs'></a>

# %% [markdown]
# 1. [<cite data-cite='taylor1999synthesis'>《射电天文学中的综合成像 II》（讲次 1、2）</cite> &#10548;](http://adsabs.harvard.edu/abs/1999sira.conf.....T)：适合作为总体入门。
# 2. [<cite data-cite='thompson2008interferometry'>《射电天文学中的干涉与综合》（第 1.3、12、14 章）</cite> &#10548;](http://onlinelibrary.wiley.com/book/10.1002/9783527617845)：可作为《射电天文学中的综合成像 II》前两讲的重要补充阅读。
# 3. [<cite data-cite='1966raas.book.....K'>《射电天文学》（第 6 至 10 章）&#10548;</cite>](http://adsabs.harvard.edu/abs/1966raas.book.....K)：适合了解射电天文学的整体图景。

# %% [markdown]
# ***
#
# * 下一章：[5. 成像](../5_Imaging/5_0_introduction.ipynb)
