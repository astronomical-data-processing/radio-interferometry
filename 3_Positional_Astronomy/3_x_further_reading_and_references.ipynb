# %% [markdown]
# ***
#
# * [总目录](../0_Introduction/0_introduction.ipynb)
# * [术语表](../0_Introduction/1_glossary.ipynb)
# * [第 3 章：干涉测量中的位置天文学](3_0_introduction.ipynb)
#     * 上一节：[3.4 方向余弦、相位中心与局部成像坐标](3_4_direction_cosine_coordinates.ipynb)
#     * 下一节：[第 4 章：可见度空间](../4_Visibility_Space/4_0_introduction.ipynb)
#
# ***

# %% [markdown]
# 导入标准模块:

# %%
import numpy as np
import matplotlib.pyplot as plt
try:
    from IPython.display import HTML
except ImportError:
    def HTML(*args, **kwargs):
        return None
# %matplotlib inline
HTML('../style/course.css')
plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['font.size'] = 12

# %%
try:
    from IPython.display import HTML
except ImportError:
    def HTML(*args, **kwargs):
        return None
HTML('../style/code_toggle.html')

# %% [markdown]
# ## 3.x 延伸阅读与参考文献

# %% [markdown]
# 本章的阅读材料建议分成三类：一类帮助你补充位置天文学和参考系统的背景；一类直接服务于射电干涉几何；还有一类给出实际软件与标准框架，帮助你把课堂公式接到现代数据处理流程上。

# %% [markdown]
# ### 位置天文学与参考系统
#
# * [Practical Astronomy with your Calculator or Spreadsheet](https://www.cambridge.org/core/books/practical-astronomy-with-your-calculator-or-spreadsheet/coordinate-systems/01F111D3505038668441D3715414C40F)
#   适合系统复习坐标系统、时间系统以及若干基础观测几何概念。它比本章更接近传统位置天文学教材，可作为坐标与时间变量的补充背景。
# * [JPL Horizons Manual](https://ssd.jpl.nasa.gov/horizons/manual.html)
#   若你想进一步理解参考架、观测者位置、视位置与星历服务之间的关系，这份官方手册非常有价值。它体现了现代天文软件如何严肃处理参考系统问题。

# %% [markdown]
# ### 射电干涉核心教材
#
# * [Essential Radio Astronomy（NRAO）](https://www.cv.nrao.edu/~sransom/web/Ch3.html)
#   一套公开的射电天文学课程讲义，特别适合把赤道坐标、时角、本地天空和干涉仪几何放进同一条叙事链里理解。
# * [Interferometry and Synthesis in Radio Astronomy](https://www.loc.gov/item/2019756474)
#   这是射电干涉领域最经典的教材之一。与本章最直接相关的是其关于几何关系、两单元干涉仪和可见度响应的章节，它会把本章的 $(H,\delta)$ 与 `(l,m,n)` 进一步接到 `u,v,w` 和可见度积分上。
# * [Tools of Radio Astronomy](https://link.springer.com/book/10.1007/978-3-642-39950-3)
#   适合希望把单天线观测、射电辐射基础和干涉测量几何放在更宽广背景下通读的读者。

# %% [markdown]
# ### 现代软件与实践框架
#
# * [Astropy Coordinates Documentation](https://docs.astropy.org/en/stable/coordinates/index.html)
#   如果你想把本章公式直接落实到 Python 工作流中，这份文档非常重要。`SkyCoord`、`ICRS`、`AltAz`、`EarthLocation` 等对象正是现代坐标变换实践中最常见的工具。
# * 各阵列的调度与观测准备软件文档
#   例如 CASA、MeerKAT/EVN/VLBI 相关的观测准备工具，通常都会在本章的基础上进一步加入阵列工程约束、扫描策略和指向模型。

# %% [markdown]
# ### 课程与暑校材料
#
# * [NRAO Synthesis Imaging Workshop Lectures](https://science.nrao.edu/science/meetings/2018/16th-synthesis-imaging-workshop/16th-synthesis-imaging-workshop-lectures)
#   如果你想继续把本章内容向“为什么地球自转会填充 `uv` 覆盖”推进，这类课程讲义是非常好的桥梁材料。
# * 各类 VLBI/射电干涉暑校与观测学校
#   这类材料通常最擅长把源目录、调度、相位中心、校准策略和成像流程串起来。阅读时建议特别留意其中关于 hour angle coverage、elevation limits、phase-referencing 和 wide-field imaging 的讨论。

# %% [markdown]
# #### 阅读建议
#
# * 如果你觉得“坐标定义还不够稳”，先看 `Practical Astronomy` 与 `Astropy` 文档；
# * 如果你已经能熟练处理 `RA/Dec`、`HA/LST` 和 `Alt/Az`，下一步应当进入 `Interferometry and Synthesis in Radio Astronomy` 或 NRAO 公开课程；
# * 如果你的目标是后续数据处理而不是天体测量细节，那么最值得反复回看的其实是本章第 3.2 到 3.4 节：时角、可观测性和相位中心，这三者会在后续章节不断出现。

# %% [markdown]
# ***
#
# 下一节：[第 4 章：可见度空间](../4_Visibility_Space/4_0_introduction.ipynb)
